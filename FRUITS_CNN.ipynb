# %% [markdown]
# <a href="https://colab.research.google.com/github/LeTrungDunggg/LeTrungDunggg/blob/main/FRUITS_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam,SGD
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Tạo ra class ImageDataGenerator để chỉnh sửa ảnh 
train_datagen=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
training_data=train_datagen.flow_from_directory('/content/drive/MyDrive/AI/HW13/FRUITS_CNN/train',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 1035 images belonging to 10 classes.

# %%
validation_data=train_datagen.flow_from_directory('/content/drive/MyDrive/AI/HW13/FRUITS_CNN/validation',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 109 images belonging to 10 classes.

# %%
training_data.class_indices
# Out:
# {'carambola': 0,
#  'coconut': 1,
#  'durian': 2,
#  'gauva': 3,
#  'grape': 4,
#  'mango': 5,
#  'mangosteen': 6,
#  'orange': 7,
#  'pear': 8,
#  'tomato': 9}

# %%
model=Sequential()
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(256,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 256 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(256,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(512,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 512 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(512,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(512,activation='relu',kernel_initializer='he_uniform'))
model.add(Dense(512,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 150, 150, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 256)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 18, 18, 512)       1180160
#
#  conv2d_7 (Conv2D)           (None, 18, 18, 512)       2359808
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 512)        0
#  2D)
#
# ...

# %%
opt=SGD(lr=0.01,momentum=0.9)
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
history=model.fit(training_data,epochs=500,batch_size=100,verbose=1, validation_data=validation_data, callbacks=[EarlyStopping(monitor='val_loss', patience=30)])
# Out:
# Epoch 1/500
# 33/33 [==============================] - 363s 10s/step - loss: 2.8521 - accuracy: 0.1014 - val_loss: 2.1512 - val_accuracy: 0.1101
# Epoch 2/500
# 33/33 [==============================] - 15s 444ms/step - loss: 2.1666 - accuracy: 0.1623 - val_loss: 2.1010 - val_accuracy: 0.2294
# Epoch 3/500
# 33/33 [==============================] - 15s 445ms/step - loss: 2.0394 - accuracy: 0.2058 - val_loss: 1.9822 - val_accuracy: 0.2385
# Epoch 4/500
# 33/33 [==============================] - 15s 445ms/step - loss: 1.9700 - accuracy: 0.2135 - val_loss: 1.9159 - val_accuracy: 0.3119
# Epoch 5/500
# 33/33 [==============================] - 15s 444ms/step - loss: 1.9681 - accuracy: 0.2184 - val_loss: 1.9873 - val_accuracy: 0.2569
# Epoch 6/500
# 33/33 [==============================] - 15s 445ms/step - loss: 1.9186 - accuracy: 0.2367 - val_loss: 1.8218 - val_accuracy: 0.2569
# Epoch 7/500
# ...

# %%
Score=model.evaluate(validation_data,verbose=0)
print('Test loss',Score[0])
print('Test accuary', Score[1])
# Out:
# Test loss 1.7372791767120361
# Test accuary 0.6697247624397278

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
model.save("Final_Fruits.h5")

# %%
model_CNN=load_model('Final_Fruits.h5')

# %%
img=load_img('/content/drive/MyDrive/AI/HW13/FRUITS_CNN/test/khe.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='carambola'
if round(result[0][1])==1:
  prediction='coconut'
if round(result[0][2])==1:
  prediction='durian'
if round(result[0][3])==1:
  prediction='gauva'
if round(result[0][4])==1:
  prediction='grape'
if round(result[0][5])==1:
  prediction='mango'
if round(result[0][6])==1:
  prediction='mangosteen'
if round(result[0][7])==1:
  prediction='orange'
if round(result[0][8])==1:
  prediction='pear'
if round(result[0][9])==1:
  prediction='tomato'
print(prediction)
# Out:
# carambola

# %%
img=load_img('/content/drive/MyDrive/AI/HW13/FRUITS_CNN/test/saurieng1.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='carambola'
if round(result[0][1])==1:
  prediction='coconut'
if round(result[0][2])==1:
  prediction='durian'
if round(result[0][3])==1:
  prediction='gauva'
if round(result[0][4])==1:
  prediction='grape'
if round(result[0][5])==1:
  prediction='mango'
if round(result[0][6])==1:
  prediction='mangosteen'
if round(result[0][7])==1:
  prediction='orange'
if round(result[0][8])==1:
  prediction='pear'
if round(result[0][9])==1:
  prediction='tomato'
print(prediction)
# Out:
# durian

# %%
img=load_img('/content/drive/MyDrive/AI/HW13/FRUITS_CNN/test/saurieng3.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='carambola'
if round(result[0][1])==1:
  prediction='coconut'
if round(result[0][2])==1:
  prediction='durian'
if round(result[0][3])==1:
  prediction='gauva'
if round(result[0][4])==1:
  prediction='grape'
if round(result[0][5])==1:
  prediction='mango'
if round(result[0][6])==1:
  prediction='mangosteen'
if round(result[0][7])==1:
  prediction='orange'
if round(result[0][8])==1:
  prediction='pear'
if round(result[0][9])==1:
  prediction='tomato'
print(prediction)
# Out:
# durian

# %%
img=load_img('/content/drive/MyDrive/AI/HW13/FRUITS_CNN/test/oi.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='carambola'
if round(result[0][1])==1:
  prediction='coconut'
if round(result[0][2])==1:
  prediction='durian'
if round(result[0][3])==1:
  prediction='gauva'
if round(result[0][4])==1:
  prediction='grape'
if round(result[0][5])==1:
  prediction='mango'
if round(result[0][6])==1:
  prediction='mangosteen'
if round(result[0][7])==1:
  prediction='orange'
if round(result[0][8])==1:
  prediction='pear'
if round(result[0][9])==1:
  prediction='tomato'
print(prediction)
# Out:
# gauva

# %%
img=load_img('/content/drive/MyDrive/AI/HW13/FRUITS_CNN/test/nho1.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='carambola'
if round(result[0][1])==1:
  prediction='coconut'
if round(result[0][2])==1:
  prediction='durian'
if round(result[0][3])==1:
  prediction='gauva'
if round(result[0][4])==1:
  prediction='grape'
if round(result[0][5])==1:
  prediction='mango'
if round(result[0][6])==1:
  prediction='mangosteen'
if round(result[0][7])==1:
  prediction='orange'
if round(result[0][8])==1:
  prediction='pear'
if round(result[0][9])==1:
  prediction='tomato'
print(prediction)
# Out:
# grape

# %%
img=load_img('/content/drive/MyDrive/AI/HW13/FRUITS_CNN/test/xoai.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='carambola'
if round(result[0][1])==1:
  prediction='coconut'
if round(result[0][2])==1:
  prediction='durian'
if round(result[0][3])==1:
  prediction='gauva'
if round(result[0][4])==1:
  prediction='grape'
if round(result[0][5])==1:
  prediction='mango'
if round(result[0][6])==1:
  prediction='mangosteen'
if round(result[0][7])==1:
  prediction='orange'
if round(result[0][8])==1:
  prediction='pear'
if round(result[0][9])==1:
  prediction='tomato'
print(prediction)
# Out:
# mango

# %%
img=load_img('/content/drive/MyDrive/AI/HW13/FRUITS_CNN/test/xoai2.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='carambola'
elif round(result[0][1])==1:
  prediction='coconut'
if round(result[0][2])==1:
  prediction='durian'
if round(result[0][3])==1:
  prediction='gauva'
if round(result[0][4])==1:
  prediction='grape'
if round(result[0][5])==1:
  prediction='mango'
if round(result[0][6])==1:
  prediction='mangosteen'
if round(result[0][7])==1:
  prediction='orange'
if round(result[0][8])==1:
  prediction='pear'
if round(result[0][9])==1:
  prediction='tomato'
print(prediction)
# Out:
# mango

# %%
img=load_img('/content/drive/MyDrive/AI/HW13/FRUITS_CNN/test/mangcut.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='carambola'
if round(result[0][1])==1:
  prediction='coconut'
if round(result[0][2])==1:
  prediction='durian'
if round(result[0][3])==1:
  prediction='gauva'
if round(result[0][4])==1:
  prediction='grape'
if round(result[0][5])==1:
  prediction='mango'
if round(result[0][6])==1:
  prediction='mangosteen'
if round(result[0][7])==1:
  prediction='orange'
if round(result[0][8])==1:
  prediction='pear'
if round(result[0][9])==1:
  prediction='tomato'
print(prediction)
# Out:
# mangosteen

# %%
img=load_img('/content/drive/MyDrive/AI/HW13/FRUITS_CNN/test/mangcut2.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='carambola'
if round(result[0][1])==1:
  prediction='coconut'
if round(result[0][2])==1:
  prediction='durian'
if round(result[0][3])==1:
  prediction='gauva'
if round(result[0][4])==1:
  prediction='grape'
if round(result[0][5])==1:
  prediction='mango'
if round(result[0][6])==1:
  prediction='mangosteen'
if round(result[0][7])==1:
  prediction='orange'
if round(result[0][8])==1:
  prediction='pear'
if round(result[0][9])==1:
  prediction='tomato'
print(prediction)
# Out:
# mangosteen

# %%
img=load_img('/content/drive/MyDrive/AI/HW13/FRUITS_CNN/test/cam.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='carambola'
if round(result[0][1])==1:
  prediction='coconut'
if round(result[0][2])==1:
  prediction='durian'
if round(result[0][3])==1:
  prediction='gauva'
if round(result[0][4])==1:
  prediction='grape'
if round(result[0][5])==1:
  prediction='mango'
if round(result[0][6])==1:
  prediction='mangosteen'
if round(result[0][7])==1:
  prediction='orange'
if round(result[0][8])==1:
  prediction='pear'
if round(result[0][9])==1:
  prediction='tomato'
print(prediction)
# Out:
# orange

# %%
img=load_img('/content/drive/MyDrive/AI/HW13/FRUITS_CNN/test/cam1.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='carambola'
if round(result[0][1])==1:
  prediction='coconut'
if round(result[0][2])==1:
  prediction='durian'
if round(result[0][3])==1:
  prediction='gauva'
if round(result[0][4])==1:
  prediction='grape'
if round(result[0][5])==1:
  prediction='mango'
if round(result[0][6])==1:
  prediction='mangosteen'
if round(result[0][7])==1:
  prediction='orange'
if round(result[0][8])==1:
  prediction='pear'
if round(result[0][9])==1:
  prediction='tomato'
print(prediction)
# Out:
# orange

# %%
img=load_img('/content/drive/MyDrive/AI/HW13/FRUITS_CNN/test/le1.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='carambola'
if round(result[0][1])==1:
  prediction='coconut'
if round(result[0][2])==1:
  prediction='durian'
if round(result[0][3])==1:
  prediction='gauva'
if round(result[0][4])==1:
  prediction='grape'
if round(result[0][5])==1:
  prediction='mango'
if round(result[0][6])==1:
  prediction='mangosteen'
if round(result[0][7])==1:
  prediction='orange'
if round(result[0][8])==1:
  prediction='pear'
if round(result[0][9])==1:
  prediction='tomato'
print(prediction)
# Out:
# pear

# %%
img=load_img('/content/drive/MyDrive/AI/HW13/FRUITS_CNN/test/le2.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='carambola'
if round(result[0][1])==1:
  prediction='coconut'
if round(result[0][2])==1:
  prediction='durian'
if round(result[0][3])==1:
  prediction='gauva'
if round(result[0][4])==1:
  prediction='grape'
if round(result[0][5])==1:
  prediction='mango'
if round(result[0][6])==1:
  prediction='mangosteen'
if round(result[0][7])==1:
  prediction='orange'
if round(result[0][8])==1:
  prediction='pear'
if round(result[0][9])==1:
  prediction='tomato'
print(prediction)
# Out:
# pear

# %%
img=load_img('/content/drive/MyDrive/AI/HW13/FRUITS_CNN/test/cachua.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='carambola'
if round(result[0][1])==1:
  prediction='coconut'
if round(result[0][2])==1:
  prediction='durian'
if round(result[0][3])==1:
  prediction='gauva'
if round(result[0][4])==1:
  prediction='grape'
if round(result[0][5])==1:
  prediction='mango'
if round(result[0][6])==1:
  prediction='mangosteen'
if round(result[0][7])==1:
  prediction='orange'
if round(result[0][8])==1:
  prediction='pear'
if round(result[0][9])==1:
  prediction='tomato'
print(prediction)
# Out:
# tomato

# %%
img=load_img('/content/drive/MyDrive/AI/HW13/FRUITS_CNN/test/dua2.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='carambola'
if round(result[0][1])==1:
  prediction='coconut'
if round(result[0][2])==1:
  prediction='durian'
if round(result[0][3])==1:
  prediction='gauva'
if round(result[0][4])==1:
  prediction='grape'
if round(result[0][5])==1:
  prediction='mango'
if round(result[0][6])==1:
  prediction='mangosteen'
if round(result[0][7])==1:
  prediction='orange'
if round(result[0][8])==1:
  prediction='pear'
if round(result[0][9])==1:
  prediction='tomato'
print(prediction)
# Out:
# coconut
